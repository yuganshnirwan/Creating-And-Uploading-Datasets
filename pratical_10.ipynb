# %% [markdown]
# <a href="https://colab.research.google.com/github/yuganshnirwan/Creating-And-Uploading-Datasets/blob/main/pratical_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aarya Yugansh Nirwan
# ##PRN:25070123004
# ###Batch EnTC A1

# %%
import pandas as pd

data={
    'Roll_No':[1,2,3,4,5],
    'Gender':['F','M','F','M','F'],
    'Department':['ENTC','RA','Mech','AIML','CSE'],
    'CGPA':[9.6,9.5,8.4,8.5,7.6]
}

df=pd.DataFrame(data)

df.to_csv('student_database.csv',index=False)
df
# Out:
#    Roll_No Gender Department  CGPA
# 0        1      F       ENTC   9.6
# 1        2      M         RA   9.5
# 2        3      F       Mech   8.4
# 3        4      M       AIML   8.5
# 4        5      F        CSE   7.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll_No     5 non-null      int64
#  1   Gender      5 non-null      object
#  2   Department  5 non-null      object
#  3   CGPA        5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df.shape
# Out:
# (5, 4)

# %%
#Access information about a column
df['Department']
# Out:
# 0    ENTC
# 1      RA
# 2    Mech
# 3    AIML
# 4     CSE
# Name: Department, dtype: object

# %%
#Access information about a row
df.loc[2]
# Out:
# Roll_No          3
# Gender           F
# Department    Mech
# CGPA           8.4
# Name: 2, dtype: object

# %%
#Data type of each column
df.dtypes
# Out:
# Roll_No         int64
# Gender         object
# Department     object
# CGPA          float64
# dtype: object

# %%
#Perform mean, median, mode
mean=df['CGPA'].mean()
median=df['CGPA'].median()
mode=df['Department'].mode()

print(mean)
print(median)
print(mode)
# Out:
# 8.72
# 8.5
# 0    AIML
# 1     CSE
# 2    ENTC
# 3    Mech
# 4      RA
# Name: Department, dtype: object

# %%
#Insert a new column
df['Grade']=[96,94,81,85,71]
df
# Out:
#    Roll_No Gender Department  CGPA  Grade
# 0        1      F       ENTC   9.6     96
# 1        2      M         RA   9.5     94
# 2        3      F       Mech   8.4     81
# 3        4      M       AIML   8.5     85
# 4        5      F        CSE   7.6     71

# %%
#Delete a column
df.drop('Gender',axis=1,inplace=True)
df
# Out:
#    Roll_No Department  CGPA  Grade
# 0        1       ENTC   9.6     96
# 1        2         RA   9.5     94
# 2        3       Mech   8.4     81
# 3        4       AIML   8.5     85
# 4        5        CSE   7.6     71

# %%
#CGPA of Topper
df.loc[0,'CGPA']
# Out:
# np.float64(9.6)

# %%
df.iloc[4,2]
# Out:
# np.float64(7.6)

# %%
import numpy as np
df=pd.read_csv('/content/Cars93.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23466/2049544915.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 df=pd.read_csv('/content/Cars93.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.size
# Out:
# 20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll_No     5 non-null      int64
#  1   Department  5 non-null      object
#  2   CGPA        5 non-null      float64
#  3   Grade       5 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 292.0+ bytes

# %%
df.shape
# Out:
# (5, 4)

# %%
df.head()
# Out:
#    Roll_No Department  CGPA  Grade
# 0        1       ENTC   9.6     96
# 1        2         RA   9.5     94
# 2        3       Mech   8.4     81
# 3        4       AIML   8.5     85
# 4        5        CSE   7.6     71

# %%
df.tail()
# Out:
#    Roll_No Department  CGPA  Grade
# 0        1       ENTC   9.6     96
# 1        2         RA   9.5     94
# 2        3       Mech   8.4     81
# 3        4       AIML   8.5     85
# 4        5        CSE   7.6     71
